# %% [markdown]
# # 06 — Modeling
#
# ## HDBSCAN — route clustering
# Input: `data/processed/route_features.parquet`
# Goal: cluster routes by performance profile (delay, volume, reliability).
#
# ## Prophet — time series forecasting
# Input: on-time parquet, T-100 parquet
# Goal: forecast passenger volume and on-time rates per airport through 2027.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
from config import PROCESSED_DATA_PATH

PROC = PROJECT_ROOT / PROCESSED_DATA_PATH

# %% [markdown]
# ## 1. HDBSCAN — route clustering

# %% [markdown]
# ## 2. Prophet — passenger volume forecast per airport

# %% [markdown]
# ## 3. Prophet — on-time rate forecast per airport
